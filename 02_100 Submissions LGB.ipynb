# %% [markdown]
# # NCAA March Machine Learning Mania 2025 – Competitive Submission Notebook
#
# This notebook implements an ensemble pipeline that:
# 1. Computes Elo ratings from historical regular season detailed results.
# 2. Creates training data using an Elo difference (EloDiff) feature and observed game margin.
# 3. Trains separate LightGBM regression models for men's and women's games to predict margin.
# 4. Converts predicted margins to win probabilities using a logistic transform.
# 5. Loops over 100 iterations (each with a different random seed / slight hyperparameter variation)
#    to generate 100 candidate submission files.
#
# *Note: This code is designed for competitive use and is more elaborate than a simple demonstration.*

# %%
# Import Libraries & Setup
import glob, os
import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV

import warnings
warnings.filterwarnings("ignore")

sns.set(style="whitegrid", context="notebook", font_scale=1.1)

print("Libraries imported and default styles set.")

import time
start_time = time.time()
# Out:
# Libraries imported and default styles set.

# %%
input_folder = r"C:\Users\Hi\My Works\My Py Scripts\Git Repos\48_March-achine-learning-mania-2025\Input"
csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

dataframes = {}
for file in csv_files:
    key = os.path.splitext(os.path.basename(file))[0]
    try:
        # Using 'latin-1' encoding to avoid Unicode issues
        dataframes[key] = pd.read_csv(file, low_memory=False, encoding="latin-1")
        print(f"Loaded {key} with shape {dataframes[key].shape}")
    except Exception as e:
        print(f"Error loading {file}: {e}")
print("\nAll CSV files loaded automatically.")

end_time = time.time()
print(f"\nTotal Execution Time: {end_time - start_time:.2f} seconds")
# Out:
# Loaded Cities with shape (502, 3)
# Loaded Conferences with shape (51, 2)
# Loaded MConferenceTourneyGames with shape (6491, 5)
# Loaded MGameCities with shape (84509, 6)
# Loaded MMasseyOrdinals with shape (5435396, 5)
# Loaded MNCAATourneyCompactResults with shape (2518, 8)
# Loaded MNCAATourneyDetailedResults with shape (1382, 34)
# Loaded MNCAATourneySeedRoundSlots with shape (776, 5)
# Loaded MNCAATourneySeeds with shape (2558, 3)
# Loaded MNCAATourneySlots with shape (2519, 4)
# Loaded MRegularSeasonCompactResults with shape (190771, 8)
# Loaded MRegularSeasonDetailedResults with shape (116723, 34)
# Loaded MSeasons with shape (41, 6)
# Loaded MSecondaryTourneyCompactResults with shape (1809, 9)
# Loaded MSecondaryTourneyTeams with shape (1836, 3)
# Loaded MTeamCoaches with shape (13533, 5)
# Loaded MTeamConferences with shape (13388, 3)
# Loaded MTeams with shape (380, 4)
# Loaded MTeamSpellings with shape (1177, 2)
# Loaded SampleSubmissionStage1 with shape (507108, 2)
# Loaded SeedBenchmarkStage1 with shape (507108, 2)
# Loaded WConferenceTourneyGames with shape (6113, 5)
# Loaded WGameCities with shape (81342, 6)
# Loaded WNCAATourneyCompactResults with shape (1650, 8)
# Loaded WNCAATourneyDetailedResults with shape (894, 34)
# Loaded WNCAATourneySeeds with shape (1676, 3)
# Loaded WNCAATourneySlots with shape (1713, 4)
# Loaded WRegularSeasonCompactResults with shape (134961, 8)
# Loaded WRegularSeasonDetailedResults with shape (79639, 34)
# Loaded WSeasons with shape (28, 6)
# Loaded WSecondaryTourneyCompactResults with shape (828, 9)
# Loaded WSecondaryTourneyTeams with shape (824, 3)
# Loaded WTeamConferences with shape (9490, 3)
# Loaded WTeams with shape (378, 2)
# Loaded WTeamSpellings with shape (1170, 2)
#
# All CSV files loaded automatically.
#
# Total Execution Time: 2.08 seconds

# %% [markdown]
# ## Compute Elo Ratings from Historical Regular Season Detailed Results
# We use the men's and women's regular season detailed results along with the team lists.

# %%
def initialize_elo(team_ids, start_elo=1500):
    return {tid: start_elo for tid in team_ids}

def update_elo(elo_dict, teamA, teamB, scoreA, scoreB, k=20):
    ra = elo_dict[teamA]
    rb = elo_dict[teamB]
    ea = 1.0 / (1 + 10 ** ((rb - ra) / 400))
    sa = 1 if scoreA > scoreB else 0
    sb = 1 - sa
    elo_dict[teamA] = ra + k * (sa - ea)
    elo_dict[teamB] = rb + k * (sb - (1 - ea))

def compute_elo(df_games, teams_df):
    df_sorted = df_games.sort_values(by=['Season','DayNum'])
    team_ids = teams_df['TeamID'].unique()
    elo_dict = initialize_elo(team_ids)
    for idx, row in df_sorted.iterrows():
        update_elo(elo_dict, row['WTeamID'], row['LTeamID'], row['WScore'], row['LScore'])
    return elo_dict

# Get men's and women's team lists
df_MTeams = dataframes['MTeams']
df_WTeams = dataframes['WTeams']

# Use regular season detailed results for Elo calculation.
df_MReg = dataframes['MRegularSeasonDetailedResults'].copy()
df_WReg = dataframes['WRegularSeasonDetailedResults'].copy()

elo_m = compute_elo(df_MReg, df_MTeams)
elo_w = compute_elo(df_WReg, df_WTeams)
print("Computed Elo ratings for men's and women's data.")

end_time = time.time()
print(f"\nTotal Execution Time: {end_time - start_time:.2f} seconds")
# Out:
# Computed Elo ratings for men's and women's data.
#
# Total Execution Time: 11.33 seconds

# %% [markdown]
# ## Prepare Training Data for Margin Modeling
# For each game, we compute:
# - **EloDiff**: Difference in Elo ratings between the winning and losing teams.
# - **Margin**: The observed score margin (WScore - LScore).
# We do this for both men's and women's historical data.

# %%
def prepare_training_data(df, elo_dict):
    elo_diffs = []
    margins = []
    for idx, row in df.iterrows():
        # Use final Elo ratings as a proxy (could be improved with dynamic Elo)
        diff = elo_dict.get(row['WTeamID'], 1500) - elo_dict.get(row['LTeamID'], 1500)
        elo_diffs.append(diff)
        margins.append(row['WScore'] - row['LScore'])
    return pd.DataFrame({'EloDiff': elo_diffs, 'Margin': margins})

train_m = prepare_training_data(df_MReg, elo_m)
train_w = prepare_training_data(df_WReg, elo_w)
print("Prepared training data for men's and women's margin models.")
print("Men’s train data shape:", train_m.shape)
print("Women’s train data shape:", train_w.shape)

end_time = time.time()
print(f"\nTotal Execution Time: {end_time - start_time:.2f} seconds")
# Out:
# Prepared training data for men's and women's margin models.
# Men’s train data shape: (116723, 2)
# Women’s train data shape: (79639, 2)
#
# Total Execution Time: 25.83 seconds

# %% [markdown]
# ## Train LightGBM Models for Margin Prediction
# We use LightGBM regressors to predict the margin from the Elo difference.
# We train separate models for men's and women's data.

# %%
# Cell 6: Train LightGBM (GPU) + Early Stopping

def train_lgb_model(df_train, seed=42):
    """
    Trains a LightGBM regressor on EloDiff -> Margin using GPU acceleration & early stopping.
    """
    # Prepare dataset
    X = df_train[['EloDiff']]
    y = df_train['Margin']
    
    # Train/val split
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, random_state=seed
    )
    
    # GPU parameters
    params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': 'mse',
        'learning_rate': 0.01,
        'num_leaves': 31,
        'seed': seed,
        'verbose': -1,
        'device_type': 'gpu',         # or 'device': 'gpu' in older versions
        'tree_learner': 'data_parallel',  # or 'serial'/'gpu'
        'gpu_platform_id': 0,
        'gpu_device_id': 0
    }
    
    dtrain = lgb.Dataset(X_train, label=y_train)
    dval   = lgb.Dataset(X_val, label=y_val, reference=dtrain)
    
    model = lgb.train(
        params,
        dtrain,
        num_boost_round=2000,
        valid_sets=[dval],
        callbacks=[
            lgb.early_stopping(stopping_rounds=50),
            lgb.log_evaluation(period=0)
        ]
    )
    return model

print("Defined train_lgb_model function for GPU-based LightGBM.")

end_time = time.time()
print(f"\nTotal Execution Time: {end_time - start_time:.2f} seconds")
# Out:
# Defined train_lgb_model function for GPU-based LightGBM.
#
# Total Execution Time: 25.84 seconds

# %% [markdown]
# ## Define Function to Convert Margin to Win Probability
# We use a logistic transformation with a scaling factor.

# %%
def margin_to_probability(margin, scale=10.0):
    """
    Logistic transform to convert predicted margin -> win probability.
    P = 1 / [1 + 10^(-margin/scale)]
    """
    return 1.0 / (1 + 10 ** (-margin / scale))

# %% [markdown]
# ## Prepare Test Data from the Sample Submission File
# We parse the submission ID to extract Season, Team1, and Team2.

# %%
df_sub = dataframes['SampleSubmissionStage1'].copy()

def parse_id(match_id):
    season, t1, t2 = match_id.split('_')
    return int(season), int(t1), int(t2)

df_sub['Season'] = df_sub['ID'].apply(lambda x: parse_id(x)[0])
df_sub['Team1'] = df_sub['ID'].apply(lambda x: parse_id(x)[1])
df_sub['Team2'] = df_sub['ID'].apply(lambda x: parse_id(x)[2])
print("Test data prepared from the submission file.")
print(df_sub.head())
# Out:
# Test data prepared from the submission file.
#                ID  Pred  Season  Team1  Team2
# 0  2021_1101_1102   0.5    2021   1101   1102
# 1  2021_1101_1103   0.5    2021   1101   1103
# 2  2021_1101_1104   0.5    2021   1101   1104
# 3  2021_1101_1105   0.5    2021   1101   1105
# 4  2021_1101_1106   0.5    2021   1101   1106

# %% [markdown]
# ## Define a Function to Predict the Outcome for a Given Match
# For each matchup, we compute the Elo difference using the final Elo ratings,
# predict the margin using the corresponding LightGBM model (men's or women's),
# and convert that margin to a win probability.

# %%
def predict_match(season, team1, team2,
                  elo_m, elo_w,
                  model_m, model_w):
    """
    If both teams < 2000 => men’s
    If both teams >= 3000 => women’s
    Otherwise default prob=0.5
    """
    if team1 < 2000 and team2 < 2000:
        e1 = elo_m.get(team1, 1500)
        e2 = elo_m.get(team2, 1500)
        elo_diff = e1 - e2
        margin_pred = model_m.predict(pd.DataFrame({'EloDiff': [elo_diff]}))[0]
        prob = margin_to_probability(margin_pred)
    elif team1 >= 3000 and team2 >= 3000:
        e1 = elo_w.get(team1, 1500)
        e2 = elo_w.get(team2, 1500)
        elo_diff = e1 - e2
        margin_pred = model_w.predict(pd.DataFrame({'EloDiff': [elo_diff]}))[0]
        prob = margin_to_probability(margin_pred)
    else:
        # If "mixed" or out-of-range, fallback to 0.5
        prob = 0.5
    return prob

# %% [markdown]
# ## Generate Ensemble Predictions & Save 100 Submission Files
# We loop over 100 iterations. In each iteration, we slightly vary the model seeds (and thus hyperparameters)
# by retraining the LightGBM models using a different random seed. We then predict for every matchup in the test set,
# and save the resulting predictions to a separate CSV file.

# %%
from datetime import datetime
import random

# We'll generate 100 submissions.
num_submissions = 100

# Create a folder to save submissions (if not exists)
submission_folder = "ensemble_submissions"
os.makedirs(submission_folder, exist_ok=True)

for i in range(1, num_submissions + 1):
    # Use a new seed for each iteration
    seed_val = 1000 + i
    print(f"\n=== Generating submission {i}/{num_submissions} with seed {seed_val} ===")
    
    # 1) Retrain men’s model
    model_m_i = train_lgb_model(train_m, seed=seed_val)
    # 2) Retrain women’s model
    model_w_i = train_lgb_model(train_w, seed=seed_val)
    
    # 3) Predict for each row in sample submission
    preds = []
    for idx, row in df_sub.iterrows():
        s  = row['Season']
        t1 = row['Team1']
        t2 = row['Team2']
        p  = predict_match(s, t1, t2, elo_m, elo_w, model_m_i, model_w_i)
        
        # Optional random perturbation for diversity
        p += np.random.normal(0, 0.005)   # Tiny noise
        p = np.clip(p, 0.001, 0.999)      # Keep in [0.001, 0.999]
        
        preds.append(p)
    
    # 4) Assign predictions & save
    df_sub['Pred'] = preds
    submission_filename = os.path.join(submission_folder, f"submission_gpu_{i}.csv")
    df_sub[['ID','Pred']].to_csv(submission_filename, index=False)
    print(f"Saved => {submission_filename}")
   
    end_time = time.time()
    print(f"\nTotal Execution Time: {end_time - start_time:.2f} seconds")

print("\nEnsemble submission generation complete. 100 submission files created.")
# Out:
# === Generating submission 1/100 with seed 1001 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [410]	valid_0's l2: 73.3057
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [518]	valid_0's l2: 101.719
# Saved => ensemble_submissions\submission_gpu_1.csv
#
# Total Execution Time: 369.80 seconds
#
# === Generating submission 2/100 with seed 1002 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [425]	valid_0's l2: 73.4069
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [365]	valid_0's l2: 101.967
# Saved => ensemble_submissions\submission_gpu_2.csv
#
# Total Execution Time: 708.98 seconds
#
# === Generating submission 3/100 with seed 1003 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [426]	valid_0's l2: 73.6591
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [385]	valid_0's l2: 99.7676
# Saved => ensemble_submissions\submission_gpu_3.csv
#
# Total Execution Time: 1049.78 seconds
#
# === Generating submission 4/100 with seed 1004 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	valid_0's l2: 75.0148
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [290]	valid_0's l2: 102.453
# Saved => ensemble_submissions\submission_gpu_4.csv
#
# Total Execution Time: 1392.73 seconds
#
# === Generating submission 5/100 with seed 1005 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [339]	valid_0's l2: 72.8576
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [336]	valid_0's l2: 100.896
# Saved => ensemble_submissions\submission_gpu_5.csv
#
# Total Execution Time: 1727.55 seconds
#
# === Generating submission 6/100 with seed 1006 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [352]	valid_0's l2: 73.6596
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [483]	valid_0's l2: 104.089
# Saved => ensemble_submissions\submission_gpu_6.csv
#
# Total Execution Time: 2068.17 seconds
#
# === Generating submission 7/100 with seed 1007 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [471]	valid_0's l2: 73.1743
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [432]	valid_0's l2: 102.273
# Saved => ensemble_submissions\submission_gpu_7.csv
#
# Total Execution Time: 2410.92 seconds
#
# === Generating submission 8/100 with seed 1008 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [346]	valid_0's l2: 74.4644
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [318]	valid_0's l2: 102.763
# Saved => ensemble_submissions\submission_gpu_8.csv
#
# Total Execution Time: 2746.78 seconds
#
# === Generating submission 9/100 with seed 1009 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [367]	valid_0's l2: 72.9695
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [327]	valid_0's l2: 102.722
# Saved => ensemble_submissions\submission_gpu_9.csv
#
# Total Execution Time: 3082.81 seconds
#
# === Generating submission 10/100 with seed 1010 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [469]	valid_0's l2: 75.5259
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [510]	valid_0's l2: 101.818
# Saved => ensemble_submissions\submission_gpu_10.csv
#
# Total Execution Time: 3430.31 seconds
#
# === Generating submission 11/100 with seed 1011 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l2: 73.7244
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [483]	valid_0's l2: 103.369
# Saved => ensemble_submissions\submission_gpu_11.csv
#
# Total Execution Time: 3770.53 seconds
#
# === Generating submission 12/100 with seed 1012 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's l2: 73.9476
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [394]	valid_0's l2: 101.937
# Saved => ensemble_submissions\submission_gpu_12.csv
#
# Total Execution Time: 4102.52 seconds
#
# === Generating submission 13/100 with seed 1013 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [394]	valid_0's l2: 74.1318
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [397]	valid_0's l2: 104.108
# Saved => ensemble_submissions\submission_gpu_13.csv
#
# Total Execution Time: 4437.69 seconds
#
# === Generating submission 14/100 with seed 1014 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [415]	valid_0's l2: 73.5524
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [500]	valid_0's l2: 102.705
# Saved => ensemble_submissions\submission_gpu_14.csv
#
# Total Execution Time: 4779.61 seconds
#
# === Generating submission 15/100 with seed 1015 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [309]	valid_0's l2: 72.3066
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [361]	valid_0's l2: 101.803
# Saved => ensemble_submissions\submission_gpu_15.csv
#
# Total Execution Time: 5110.65 seconds
#
# === Generating submission 16/100 with seed 1016 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [389]	valid_0's l2: 73.0006
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [285]	valid_0's l2: 102.215
# Saved => ensemble_submissions\submission_gpu_16.csv
#
# Total Execution Time: 5443.98 seconds
#
# === Generating submission 17/100 with seed 1017 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [315]	valid_0's l2: 73.5944
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [430]	valid_0's l2: 99.31
# Saved => ensemble_submissions\submission_gpu_17.csv
#
# Total Execution Time: 5778.86 seconds
#
# === Generating submission 18/100 with seed 1018 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [448]	valid_0's l2: 73.1523
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [450]	valid_0's l2: 100.735
# Saved => ensemble_submissions\submission_gpu_18.csv
#
# Total Execution Time: 6120.99 seconds
#
# === Generating submission 19/100 with seed 1019 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [428]	valid_0's l2: 72.5254
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [276]	valid_0's l2: 101.037
# Saved => ensemble_submissions\submission_gpu_19.csv
#
# Total Execution Time: 6455.93 seconds
#
# === Generating submission 20/100 with seed 1020 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [417]	valid_0's l2: 74.8162
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l2: 101.53
# Saved => ensemble_submissions\submission_gpu_20.csv
#
# Total Execution Time: 6790.88 seconds
#
# === Generating submission 21/100 with seed 1021 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [500]	valid_0's l2: 74.5047
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [461]	valid_0's l2: 104.992
# Saved => ensemble_submissions\submission_gpu_21.csv
#
# Total Execution Time: 7135.46 seconds
#
# === Generating submission 22/100 with seed 1022 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [282]	valid_0's l2: 72.5049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [300]	valid_0's l2: 102.009
# Saved => ensemble_submissions\submission_gpu_22.csv
#
# Total Execution Time: 7465.19 seconds
#
# === Generating submission 23/100 with seed 1023 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [462]	valid_0's l2: 73.3453
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [452]	valid_0's l2: 101.588
# Saved => ensemble_submissions\submission_gpu_23.csv
#
# Total Execution Time: 7808.14 seconds
#
# === Generating submission 24/100 with seed 1024 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [342]	valid_0's l2: 74.7356
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [377]	valid_0's l2: 103.777
# Saved => ensemble_submissions\submission_gpu_24.csv
#
# Total Execution Time: 8141.43 seconds
#
# === Generating submission 25/100 with seed 1025 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [407]	valid_0's l2: 73.6904
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [358]	valid_0's l2: 100.294
# Saved => ensemble_submissions\submission_gpu_25.csv
#
# Total Execution Time: 8477.56 seconds
#
# === Generating submission 26/100 with seed 1026 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [437]	valid_0's l2: 72.5827
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [317]	valid_0's l2: 99.3302
# Saved => ensemble_submissions\submission_gpu_26.csv
#
# Total Execution Time: 8812.61 seconds
#
# === Generating submission 27/100 with seed 1027 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [586]	valid_0's l2: 74.5214
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [528]	valid_0's l2: 99.5378
# Saved => ensemble_submissions\submission_gpu_27.csv
#
# Total Execution Time: 9164.50 seconds
#
# === Generating submission 28/100 with seed 1028 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [495]	valid_0's l2: 74.557
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [450]	valid_0's l2: 103.039
# Saved => ensemble_submissions\submission_gpu_28.csv
#
# Total Execution Time: 9507.50 seconds
#
# === Generating submission 29/100 with seed 1029 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [456]	valid_0's l2: 73.0039
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [426]	valid_0's l2: 102.716
# Saved => ensemble_submissions\submission_gpu_29.csv
#
# Total Execution Time: 9847.46 seconds
#
# === Generating submission 30/100 with seed 1030 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [331]	valid_0's l2: 71.949
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [405]	valid_0's l2: 98.0094
# Saved => ensemble_submissions\submission_gpu_30.csv
#
# Total Execution Time: 10181.78 seconds
#
# === Generating submission 31/100 with seed 1031 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [407]	valid_0's l2: 72.4221
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [315]	valid_0's l2: 101.688
# Saved => ensemble_submissions\submission_gpu_31.csv
#
# Total Execution Time: 10515.57 seconds
#
# === Generating submission 32/100 with seed 1032 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [375]	valid_0's l2: 72.2051
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [522]	valid_0's l2: 99.5876
# Saved => ensemble_submissions\submission_gpu_32.csv
#
# Total Execution Time: 10857.40 seconds
#
# === Generating submission 33/100 with seed 1033 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [505]	valid_0's l2: 73.7663
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [352]	valid_0's l2: 102.778
# Saved => ensemble_submissions\submission_gpu_33.csv
#
# Total Execution Time: 11197.38 seconds
#
# === Generating submission 34/100 with seed 1034 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [420]	valid_0's l2: 73.9637
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [475]	valid_0's l2: 103.259
# Saved => ensemble_submissions\submission_gpu_34.csv
#
# Total Execution Time: 11540.63 seconds
#
# === Generating submission 35/100 with seed 1035 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [356]	valid_0's l2: 74.4412
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [332]	valid_0's l2: 100.613
# Saved => ensemble_submissions\submission_gpu_35.csv
#
# Total Execution Time: 11873.08 seconds
#
# === Generating submission 36/100 with seed 1036 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [392]	valid_0's l2: 72.1443
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [380]	valid_0's l2: 99.6138
# Saved => ensemble_submissions\submission_gpu_36.csv
#
# Total Execution Time: 12208.82 seconds
#
# === Generating submission 37/100 with seed 1037 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [288]	valid_0's l2: 73.4066
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [276]	valid_0's l2: 99.6338
# Saved => ensemble_submissions\submission_gpu_37.csv
#
# Total Execution Time: 12537.66 seconds
#
# === Generating submission 38/100 with seed 1038 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [351]	valid_0's l2: 73.6481
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [449]	valid_0's l2: 103.356
# Saved => ensemble_submissions\submission_gpu_38.csv
#
# Total Execution Time: 12875.35 seconds
#
# === Generating submission 39/100 with seed 1039 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [468]	valid_0's l2: 72.7144
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [420]	valid_0's l2: 100.74
# Saved => ensemble_submissions\submission_gpu_39.csv
#
# Total Execution Time: 13216.47 seconds
#
# === Generating submission 40/100 with seed 1040 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [401]	valid_0's l2: 75.0327
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [332]	valid_0's l2: 101.599
# Saved => ensemble_submissions\submission_gpu_40.csv
#
# Total Execution Time: 13550.16 seconds
#
# === Generating submission 41/100 with seed 1041 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l2: 73.8253
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [354]	valid_0's l2: 104.199
# Saved => ensemble_submissions\submission_gpu_41.csv
#
# Total Execution Time: 13883.18 seconds
#
# === Generating submission 42/100 with seed 1042 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [534]	valid_0's l2: 72.3391
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [382]	valid_0's l2: 103.869
# Saved => ensemble_submissions\submission_gpu_42.csv
#
# Total Execution Time: 14225.78 seconds
#
# === Generating submission 43/100 with seed 1043 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [399]	valid_0's l2: 73.5728
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [358]	valid_0's l2: 102.783
# Saved => ensemble_submissions\submission_gpu_43.csv
#
# Total Execution Time: 14561.35 seconds
#
# === Generating submission 44/100 with seed 1044 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [444]	valid_0's l2: 75.014
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [405]	valid_0's l2: 102.615
# Saved => ensemble_submissions\submission_gpu_44.csv
#
# Total Execution Time: 14900.94 seconds
#
# === Generating submission 45/100 with seed 1045 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [332]	valid_0's l2: 73.5708
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [510]	valid_0's l2: 102.366
# Saved => ensemble_submissions\submission_gpu_45.csv
#
# Total Execution Time: 15241.12 seconds
#
# === Generating submission 46/100 with seed 1046 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [346]	valid_0's l2: 72.7585
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [348]	valid_0's l2: 100.152
# Saved => ensemble_submissions\submission_gpu_46.csv
#
# Total Execution Time: 15573.22 seconds
#
# === Generating submission 47/100 with seed 1047 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [347]	valid_0's l2: 73.7087
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [464]	valid_0's l2: 102.208
# Saved => ensemble_submissions\submission_gpu_47.csv
#
# Total Execution Time: 15910.44 seconds
#
# === Generating submission 48/100 with seed 1048 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [315]	valid_0's l2: 72.1559
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [367]	valid_0's l2: 101.15
# Saved => ensemble_submissions\submission_gpu_48.csv
#
# Total Execution Time: 16242.37 seconds
#
# === Generating submission 49/100 with seed 1049 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [427]	valid_0's l2: 74.1943
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [310]	valid_0's l2: 100.187
# Saved => ensemble_submissions\submission_gpu_49.csv
#
# Total Execution Time: 16578.18 seconds
#
# === Generating submission 50/100 with seed 1050 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [366]	valid_0's l2: 72.9529
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [569]	valid_0's l2: 103.338
# Saved => ensemble_submissions\submission_gpu_50.csv
#
# Total Execution Time: 16921.70 seconds
#
# === Generating submission 51/100 with seed 1051 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [340]	valid_0's l2: 74.7965
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [577]	valid_0's l2: 102.345
# Saved => ensemble_submissions\submission_gpu_51.csv
#
# Total Execution Time: 17264.32 seconds
#
# === Generating submission 52/100 with seed 1052 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [377]	valid_0's l2: 72.7223
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's l2: 101.728
# Saved => ensemble_submissions\submission_gpu_52.csv
#
# Total Execution Time: 17598.27 seconds
#
# === Generating submission 53/100 with seed 1053 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [452]	valid_0's l2: 72.5858
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [406]	valid_0's l2: 101.175
# Saved => ensemble_submissions\submission_gpu_53.csv
#
# Total Execution Time: 17937.74 seconds
#
# === Generating submission 54/100 with seed 1054 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l2: 73.323
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [443]	valid_0's l2: 101.448
# Saved => ensemble_submissions\submission_gpu_54.csv
#
# Total Execution Time: 18274.69 seconds
#
# === Generating submission 55/100 with seed 1055 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [394]	valid_0's l2: 74.0627
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [364]	valid_0's l2: 104.86
# Saved => ensemble_submissions\submission_gpu_55.csv
#
# Total Execution Time: 18609.62 seconds
#
# === Generating submission 56/100 with seed 1056 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [402]	valid_0's l2: 73.0225
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [304]	valid_0's l2: 102.849
# Saved => ensemble_submissions\submission_gpu_56.csv
#
# Total Execution Time: 18943.04 seconds
#
# === Generating submission 57/100 with seed 1057 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [389]	valid_0's l2: 73.1222
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [454]	valid_0's l2: 101.2
# Saved => ensemble_submissions\submission_gpu_57.csv
#
# Total Execution Time: 19282.35 seconds
#
# === Generating submission 58/100 with seed 1058 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l2: 73.8654
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [350]	valid_0's l2: 102.821
# Saved => ensemble_submissions\submission_gpu_58.csv
#
# Total Execution Time: 19615.84 seconds
#
# === Generating submission 59/100 with seed 1059 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [381]	valid_0's l2: 71.9092
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [363]	valid_0's l2: 102.76
# Saved => ensemble_submissions\submission_gpu_59.csv
#
# Total Execution Time: 19950.18 seconds
#
# === Generating submission 60/100 with seed 1060 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [344]	valid_0's l2: 74.8961
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [354]	valid_0's l2: 102.589
# Saved => ensemble_submissions\submission_gpu_60.csv
#
# Total Execution Time: 20282.30 seconds
#
# === Generating submission 61/100 with seed 1061 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [401]	valid_0's l2: 73.0966
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [428]	valid_0's l2: 101.539
# Saved => ensemble_submissions\submission_gpu_61.csv
#
# Total Execution Time: 20620.84 seconds
#
# === Generating submission 62/100 with seed 1062 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [419]	valid_0's l2: 71.9545
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [353]	valid_0's l2: 103.267
# Saved => ensemble_submissions\submission_gpu_62.csv
#
# Total Execution Time: 20956.56 seconds
#
# === Generating submission 63/100 with seed 1063 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [387]	valid_0's l2: 73.8354
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [319]	valid_0's l2: 101.965
# Saved => ensemble_submissions\submission_gpu_63.csv
#
# Total Execution Time: 21290.11 seconds
#
# === Generating submission 64/100 with seed 1064 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [570]	valid_0's l2: 73.3729
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [307]	valid_0's l2: 101.196
# Saved => ensemble_submissions\submission_gpu_64.csv
#
# Total Execution Time: 21631.82 seconds
#
# === Generating submission 65/100 with seed 1065 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [572]	valid_0's l2: 74.1118
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [407]	valid_0's l2: 101.518
# Saved => ensemble_submissions\submission_gpu_65.csv
#
# Total Execution Time: 21977.42 seconds
#
# === Generating submission 66/100 with seed 1066 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [510]	valid_0's l2: 75.1894
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [369]	valid_0's l2: 100.958
# Saved => ensemble_submissions\submission_gpu_66.csv
#
# Total Execution Time: 22318.73 seconds
#
# === Generating submission 67/100 with seed 1067 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [598]	valid_0's l2: 74.1664
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [651]	valid_0's l2: 101.116
# Saved => ensemble_submissions\submission_gpu_67.csv
#
# Total Execution Time: 22676.58 seconds
#
# === Generating submission 68/100 with seed 1068 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [451]	valid_0's l2: 73.6098
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [377]	valid_0's l2: 102.661
# Saved => ensemble_submissions\submission_gpu_68.csv
#
# Total Execution Time: 23015.67 seconds
#
# === Generating submission 69/100 with seed 1069 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [382]	valid_0's l2: 73.5786
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [453]	valid_0's l2: 102.859
# Saved => ensemble_submissions\submission_gpu_69.csv
#
# Total Execution Time: 23354.59 seconds
#
# === Generating submission 70/100 with seed 1070 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [381]	valid_0's l2: 74.1272
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [504]	valid_0's l2: 102.755
# Saved => ensemble_submissions\submission_gpu_70.csv
#
# Total Execution Time: 23695.80 seconds
#
# === Generating submission 71/100 with seed 1071 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [376]	valid_0's l2: 74.24
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l2: 100.502
# Saved => ensemble_submissions\submission_gpu_71.csv
#
# Total Execution Time: 24031.26 seconds
#
# === Generating submission 72/100 with seed 1072 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [369]	valid_0's l2: 74.6592
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [502]	valid_0's l2: 104.054
# Saved => ensemble_submissions\submission_gpu_72.csv
#
# Total Execution Time: 24371.99 seconds
#
# === Generating submission 73/100 with seed 1073 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [416]	valid_0's l2: 73.9105
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [332]	valid_0's l2: 100.472
# Saved => ensemble_submissions\submission_gpu_73.csv
#
# Total Execution Time: 24706.69 seconds
#
# === Generating submission 74/100 with seed 1074 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's l2: 73.0765
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [437]	valid_0's l2: 101.294
# Saved => ensemble_submissions\submission_gpu_74.csv
#
# Total Execution Time: 25042.39 seconds
#
# === Generating submission 75/100 with seed 1075 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [408]	valid_0's l2: 72.468
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [460]	valid_0's l2: 101.639
# Saved => ensemble_submissions\submission_gpu_75.csv
#
# Total Execution Time: 25381.90 seconds
#
# === Generating submission 76/100 with seed 1076 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [328]	valid_0's l2: 74.0633
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l2: 101.249
# Saved => ensemble_submissions\submission_gpu_76.csv
#
# Total Execution Time: 25715.12 seconds
#
# === Generating submission 77/100 with seed 1077 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l2: 74.0425
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [325]	valid_0's l2: 102.643
# Saved => ensemble_submissions\submission_gpu_77.csv
#
# Total Execution Time: 26052.05 seconds
#
# === Generating submission 78/100 with seed 1078 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [418]	valid_0's l2: 73.724
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [528]	valid_0's l2: 102.87
# Saved => ensemble_submissions\submission_gpu_78.csv
#
# Total Execution Time: 26395.65 seconds
#
# === Generating submission 79/100 with seed 1079 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [514]	valid_0's l2: 74.8159
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [318]	valid_0's l2: 103.161
# Saved => ensemble_submissions\submission_gpu_79.csv
#
# Total Execution Time: 26734.03 seconds
#
# === Generating submission 80/100 with seed 1080 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [423]	valid_0's l2: 73.7704
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [530]	valid_0's l2: 101.951
# Saved => ensemble_submissions\submission_gpu_80.csv
#
# Total Execution Time: 27077.66 seconds
#
# === Generating submission 81/100 with seed 1081 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [475]	valid_0's l2: 74.0122
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [398]	valid_0's l2: 102.423
# Saved => ensemble_submissions\submission_gpu_81.csv
#
# Total Execution Time: 27417.94 seconds
#
# === Generating submission 82/100 with seed 1082 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [409]	valid_0's l2: 73.844
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [363]	valid_0's l2: 102.985
# Saved => ensemble_submissions\submission_gpu_82.csv
#
# Total Execution Time: 27753.26 seconds
#
# === Generating submission 83/100 with seed 1083 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [470]	valid_0's l2: 73.8935
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [491]	valid_0's l2: 102.734
# Saved => ensemble_submissions\submission_gpu_83.csv
#
# Total Execution Time: 28097.60 seconds
#
# === Generating submission 84/100 with seed 1084 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [440]	valid_0's l2: 72.6645
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [352]	valid_0's l2: 102.055
# Saved => ensemble_submissions\submission_gpu_84.csv
#
# Total Execution Time: 28433.29 seconds
#
# === Generating submission 85/100 with seed 1085 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [548]	valid_0's l2: 72.4161
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [527]	valid_0's l2: 101.813
# Saved => ensemble_submissions\submission_gpu_85.csv
#
# Total Execution Time: 28783.57 seconds
#
# === Generating submission 86/100 with seed 1086 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [541]	valid_0's l2: 72.6865
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [504]	valid_0's l2: 102.101
# Saved => ensemble_submissions\submission_gpu_86.csv
#
# Total Execution Time: 29130.98 seconds
#
# === Generating submission 87/100 with seed 1087 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [452]	valid_0's l2: 73.3174
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [473]	valid_0's l2: 100.247
# Saved => ensemble_submissions\submission_gpu_87.csv
#
# Total Execution Time: 29474.75 seconds
#
# === Generating submission 88/100 with seed 1088 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [338]	valid_0's l2: 72.9653
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [349]	valid_0's l2: 101.569
# Saved => ensemble_submissions\submission_gpu_88.csv
#
# Total Execution Time: 29806.96 seconds
#
# === Generating submission 89/100 with seed 1089 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [329]	valid_0's l2: 74.1684
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [484]	valid_0's l2: 103.15
# Saved => ensemble_submissions\submission_gpu_89.csv
#
# Total Execution Time: 30146.38 seconds
#
# === Generating submission 90/100 with seed 1090 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [650]	valid_0's l2: 73.8354
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [418]	valid_0's l2: 102.891
# Saved => ensemble_submissions\submission_gpu_90.csv
#
# Total Execution Time: 30495.16 seconds
#
# === Generating submission 91/100 with seed 1091 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [487]	valid_0's l2: 74.6303
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [327]	valid_0's l2: 101.838
# Saved => ensemble_submissions\submission_gpu_91.csv
#
# Total Execution Time: 30833.49 seconds
#
# === Generating submission 92/100 with seed 1092 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [420]	valid_0's l2: 75.3819
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l2: 101.04
# Saved => ensemble_submissions\submission_gpu_92.csv
#
# Total Execution Time: 31174.75 seconds
#
# === Generating submission 93/100 with seed 1093 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [622]	valid_0's l2: 73.2481
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [268]	valid_0's l2: 101.086
# Saved => ensemble_submissions\submission_gpu_93.csv
#
# Total Execution Time: 31518.23 seconds
#
# === Generating submission 94/100 with seed 1094 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l2: 73.8703
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [454]	valid_0's l2: 102.714
# Saved => ensemble_submissions\submission_gpu_94.csv
#
# Total Execution Time: 31856.47 seconds
#
# === Generating submission 95/100 with seed 1095 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [317]	valid_0's l2: 72.8349
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [478]	valid_0's l2: 99.5142
# Saved => ensemble_submissions\submission_gpu_95.csv
#
# Total Execution Time: 32193.45 seconds
#
# === Generating submission 96/100 with seed 1096 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [380]	valid_0's l2: 73.3953
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [458]	valid_0's l2: 101.62
# Saved => ensemble_submissions\submission_gpu_96.csv
#
# Total Execution Time: 32531.43 seconds
#
# === Generating submission 97/100 with seed 1097 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [348]	valid_0's l2: 73.835
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [481]	valid_0's l2: 100.708
# Saved => ensemble_submissions\submission_gpu_97.csv
#
# Total Execution Time: 32869.55 seconds
#
# === Generating submission 98/100 with seed 1098 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [442]	valid_0's l2: 72.6125
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l2: 101.15
# Saved => ensemble_submissions\submission_gpu_98.csv
#
# Total Execution Time: 33207.21 seconds
#
# === Generating submission 99/100 with seed 1099 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [489]	valid_0's l2: 74.0492
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [337]	valid_0's l2: 102.04
# Saved => ensemble_submissions\submission_gpu_99.csv
#
# Total Execution Time: 33547.30 seconds
#
# === Generating submission 100/100 with seed 1100 ===
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [536]	valid_0's l2: 72.6917
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l2: 103.693
# Saved => ensemble_submissions\submission_gpu_100.csv
#
# Total Execution Time: 33889.68 seconds
#
# Ensemble submission generation complete. 100 submission files created.
