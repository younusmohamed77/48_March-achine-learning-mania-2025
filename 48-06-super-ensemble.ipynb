# %%
# %% [markdown]
# ## 1. Import Libraries
# 
# We import all necessary packages. (Note: We are not importing the KerasRegressor wrapper to avoid pickling issues.)

# %% [code]
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor

import xgboost as xgb
import lightgbm as lgb
import catboost as cb

sns.set(style="whitegrid", context="notebook", font_scale=1.1)
start_time = time.time()
print("Libraries imported.")
# Out:
# Libraries imported.

# %%
data_folder = "/kaggle/input/march-machine-learning-mania-2025"

# Load men's and women's regular season detailed results and teams
m_reg = pd.read_csv(os.path.join(data_folder, "MRegularSeasonDetailedResults.csv"))
MTeams = pd.read_csv(os.path.join(data_folder, "MTeams.csv"))

w_reg = pd.read_csv(os.path.join(data_folder, "WRegularSeasonDetailedResults.csv"))
WTeams = pd.read_csv(os.path.join(data_folder, "WTeams.csv"))

# Load Massey ratings – assumed to contain columns "Team" and "MAS"
massey_ratings = pd.read_csv("/kaggle/input/massey/Massey Ratings New.csv")

print("Data loaded. (Men’s and Women’s results, teams, and Massey ratings)")
# Out:
# Data loaded. (Men’s and Women’s results, teams, and Massey ratings)

# %%
# %% [markdown]
# ## 3. Compute Elo Ratings
# 
# Here we compute a simple Elo rating for each team based on historical game outcomes.
# (For a production system, you’d use a more sophisticated approach.)

# %% [code]
def initialize_elo(team_ids, start_elo=1500):
    return {tid: start_elo for tid in team_ids}

def update_elo(elo_dict, teamA, teamB, scoreA, scoreB, k=20):
    ra = elo_dict[teamA]
    rb = elo_dict[teamB]
    ea = 1.0 / (1 + 10 ** ((rb - ra) / 400))
    sa = 1 if scoreA > scoreB else 0
    # Update ratings
    elo_dict[teamA] = ra + k * (sa - ea)
    elo_dict[teamB] = rb + k * ((1-sa) - (1-ea))
    
def compute_elo(df):
    df_sorted = df.sort_values(by=["Season", "DayNum"])
    teams = np.unique(np.concatenate((df_sorted["WTeamID"].unique(), df_sorted["LTeamID"].unique())))
    elo = initialize_elo(teams)
    for _, row in df_sorted.iterrows():
        update_elo(elo, row["WTeamID"], row["LTeamID"], row["WScore"], row["LScore"])
    return elo

# Compute Elo ratings using all available historical data (for demonstration, we use all seasons)
elo_m = compute_elo(m_reg)
elo_w = compute_elo(w_reg)
print("Elo ratings computed for men and women.")
# Out:
# Elo ratings computed for men and women.

# %%
# %% [markdown]
# ## 4. Compute New Ratings (Adjusted Margins)
# 
# For seasons 2019–2023, we compute a “new rating” for each team based on the average adjusted game margin.
# The adjustment adds a bonus for home games and subtracts it for away games.

# %% [code]
def compute_team_new_rating(df, team_id, bonus=2):
    margins = []
    
    # For games the team won:
    df_win = df[df["WTeamID"] == team_id].copy()
    df_win["adj_margin"] = df_win["WScore"] - df_win["LScore"]
    df_win.loc[df_win["WLoc"] == "H", "adj_margin"] += bonus
    df_win.loc[df_win["WLoc"] == "A", "adj_margin"] -= bonus
    margins.extend(df_win["adj_margin"].tolist())
    
    # For games the team lost:
    df_loss = df[df["LTeamID"] == team_id].copy()
    df_loss["adj_margin"] = -(df_loss["WScore"] - df_loss["LScore"])
    df_loss.loc[df_loss["WLoc"] == "H", "adj_margin"] -= bonus  # losing away
    df_loss.loc[df_loss["WLoc"] == "A", "adj_margin"] += bonus  # losing at home
    margins.extend(df_loss["adj_margin"].tolist())
    
    if len(margins) == 0:
        return np.nan
    return np.mean(margins)

# Filter games from seasons 2019-2023
m_reg_new = m_reg[(m_reg["Season"] >= 2019) & (m_reg["Season"] <= 2023)]
w_reg_new = w_reg[(w_reg["Season"] >= 2019) & (w_reg["Season"] <= 2023)]

team_ids_m = MTeams["TeamID"].unique()
team_ids_w = WTeams["TeamID"].unique()

new_rating_men = {tid: compute_team_new_rating(m_reg_new, tid) for tid in team_ids_m}
new_rating_women = {tid: compute_team_new_rating(w_reg_new, tid) for tid in team_ids_w}
print("New ratings computed for men and women (2019-2023).")
# Out:
# New ratings computed for men and women (2019-2023).

# %%
# %% [markdown]
# ## 5. Compute Combined Ratings
# 
# We combine Elo, the new rating, and Massey rating (from the Massey file) using weighted averages.
# **Change:** Instead of using a dummy value of 1500, we now use the actual Elo ratings computed above.
# 
# Also, we map the Massey ratings from the "Massey Ratings New.csv" file to teams based on team names.

# %% [code]
# Create mapping from team name to MAS rating.
massey_mapping = dict(zip(massey_ratings["Team"], massey_ratings["MAS"]))

# Map MAS rating onto teams (assume team names match exactly)
MTeams["CombinedMAS"] = MTeams["TeamName"].map(massey_mapping)
WTeams["CombinedMAS"] = WTeams["TeamName"].map(massey_mapping)

def compute_combined_rating(team_id, gender="M", weight_elo=0.33, weight_new=0.33, weight_massey=0.34):
    if gender == "M":
        rating_elo = elo_m.get(team_id, 1500)
        rating_new = new_rating_men.get(team_id, np.nan)
        mas = MTeams.loc[MTeams["TeamID"] == team_id, "CombinedMAS"]
    else:
        rating_elo = elo_w.get(team_id, 1500)
        rating_new = new_rating_women.get(team_id, np.nan)
        mas = WTeams.loc[WTeams["TeamID"] == team_id, "CombinedMAS"]
    rating_massey = mas.values[0] if not mas.empty else np.nan
    ratings = np.array([rating_elo, rating_new, rating_massey], dtype=float)
    weights = np.array([weight_elo, weight_new, weight_massey])
    valid = ~np.isnan(ratings)
    if valid.sum() == 0:
        return np.nan
    return np.average(ratings[valid], weights=weights[valid])

combined_rating_men = {tid: compute_combined_rating(tid, "M") for tid in team_ids_m}
combined_rating_women = {tid: compute_combined_rating(tid, "W") for tid in team_ids_w}
print("Combined ratings computed for men and women.")
# Out:
# Combined ratings computed for men and women.

# %%
# %% [markdown]
# ## 6. Prepare Training and Validation Data
# 
# For each game, we use the difference in combined ratings between the winning and losing teams as a feature.
# The target is the game margin (WScore - LScore). Training data is from seasons before 2024, and validation is season 2024.

# %% [code]
def prepare_model_data(df, gender="M"):
    X, y = [], []
    for _, row in df.iterrows():
        if gender == "M":
            r_w = combined_rating_men.get(row["WTeamID"], np.nan)
            r_l = combined_rating_men.get(row["LTeamID"], np.nan)
        else:
            r_w = combined_rating_women.get(row["WTeamID"], np.nan)
            r_l = combined_rating_women.get(row["LTeamID"], np.nan)
        if np.isnan(r_w) or np.isnan(r_l):
            continue
        X.append([r_w - r_l])
        y.append(row["WScore"] - row["LScore"])
    return np.array(X), np.array(y)

# Split data: seasons <2024 for training, 2024 for validation.
train_m = m_reg[m_reg["Season"] < 2024]
val_m = m_reg[m_reg["Season"] == 2024]
train_w = w_reg[w_reg["Season"] < 2024]
val_w = w_reg[w_reg["Season"] == 2024]

X_train_m, y_train_m = prepare_model_data(train_m, "M")
X_val_m, y_val_m = prepare_model_data(val_m, "M")
X_train_w, y_train_w = prepare_model_data(train_w, "W")
X_val_w, y_val_w = prepare_model_data(val_w, "W")

print("Training and validation data prepared for both men and women.")
# Out:
# Training and validation data prepared for both men and women.

# %%
# %% [markdown]
# ## 7. Define Candidate Models and Hyperparameter Tuning
# 
# We define a dictionary of candidate models (excluding DNN here to avoid pickling issues) and perform hyperparameter tuning using RandomizedSearchCV.
# **Change:** We set `n_jobs=1` to avoid serialization (pickling) issues.

# %% [code]
from scipy.stats import uniform, randint

models_grid = {
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    "Ridge": {
        "model": Ridge(),
        "params": {"alpha": uniform(0.1, 10)}
    },
    "Lasso": {
        "model": Lasso(max_iter=5000),
        "params": {"alpha": uniform(0.001, 1)}
    },
    "DecisionTree": {
        "model": DecisionTreeRegressor(),
        "params": {"max_depth": randint(1, 10), "min_samples_split": randint(2, 10)}
    },
    "RandomForest": {
        "model": RandomForestRegressor(random_state=42, n_jobs=1),
        "params": {"n_estimators": randint(50, 200), "max_depth": randint(1, 10)}
    },
    "ExtraTrees": {
        "model": ExtraTreesRegressor(random_state=42, n_jobs=1),
        "params": {"n_estimators": randint(50, 200), "max_depth": randint(1, 10)}
    },
    "GradientBoosting": {
        "model": GradientBoostingRegressor(random_state=42),
        "params": {"n_estimators": randint(50, 200), "learning_rate": uniform(0.01, 0.3), "max_depth": randint(1, 10)}
    },
    "XGBoost": {
        "model": xgb.XGBRegressor(tree_method="gpu_hist", random_state=42, n_jobs=1),
        "params": {"n_estimators": randint(50, 200), "learning_rate": uniform(0.01, 0.3), "max_depth": randint(1, 10)}
    },
    "LightGBM": {
        "model": lgb.LGBMRegressor(device="gpu", random_state=42),
        "params": {"n_estimators": randint(50, 200), "learning_rate": uniform(0.01, 0.3), "num_leaves": randint(20, 50)}
    },
    "CatBoost": {
        "model": cb.CatBoostRegressor(task_type="GPU", verbose=0, random_state=42),
        "params": {"iterations": randint(50, 200), "learning_rate": uniform(0.01, 0.3), "depth": randint(3, 10)}
    }
}

def tune_and_evaluate(model_obj, param_dist, X_train, y_train, X_val, y_val):
    rs = RandomizedSearchCV(model_obj, param_distributions=param_dist, 
                              n_iter=10, cv=3, scoring="neg_mean_squared_error", random_state=42,
                              error_score='raise', n_jobs=1)  # changed n_jobs to 1
    rs.fit(X_train, y_train)
    best_model = rs.best_estimator_
    y_pred = best_model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    # Convert margin predictions to probabilities (using logistic transform) for Brier calculation.
    def margin_to_probability(margin, scale=10.0):
        return 1.0 / (1 + 10 ** (-margin/scale))
    pred_prob = margin_to_probability(y_pred, scale=10.0)
    # Since in our validation set the winning team always wins, ground truth probability is 1.
    brier = np.mean((pred_prob - 1)**2)
    return best_model, rmse, brier

# Tune men's models.
men_results = {}
men_best_models = {}
print("Tuning Men's models:")
for name, info in models_grid.items():
    try:
        best_model, rmse, brier = tune_and_evaluate(info["model"], info["params"], 
                                                    X_train_m, y_train_m, X_val_m, y_val_m)
        men_results[name] = {"rmse": rmse, "brier": brier}
        men_best_models[name] = best_model
        print(f"Men's {name}: RMSE = {rmse:.4f}, Brier = {brier:.4f}")
    except Exception as e:
        print(f"Tuning men's {name} failed: {e}")

# Tune women's models.
women_results = {}
women_best_models = {}
print("\nTuning Women's models:")
for name, info in models_grid.items():
    try:
        best_model, rmse, brier = tune_and_evaluate(info["model"], info["params"], 
                                                    X_train_w, y_train_w, X_val_w, y_val_w)
        women_results[name] = {"rmse": rmse, "brier": brier}
        women_best_models[name] = best_model
        print(f"Women's {name}: RMSE = {rmse:.4f}, Brier = {brier:.4f}")
    except Exception as e:
        print(f"Tuning women's {name} failed: {e}")

print("\nMen's Model Results:")
print(men_results)
print("\nWomen's Model Results:")
print(women_results)
# Out:
# Tuning Men's models:
# Men's LinearRegression: RMSE = 8.7947, Brier = 0.0038
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Men's Ridge: RMSE = 8.7947, Brier = 0.0038
# Men's Lasso: RMSE = 8.7977, Brier = 0.0038
# Men's DecisionTree: RMSE = 8.2582, Brier = 0.0052
# Men's RandomForest: RMSE = 8.2693, Brier = 0.0051
# Men's ExtraTrees: RMSE = 8.4039, Brier = 0.0047
# Men's GradientBoosting: RMSE = 8.2658, Brier = 0.0051
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:29] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:36] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:36] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:36] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:04:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# Men's XGBoost: RMSE = 8.2652, Brier = 0.0050
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.002714 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000625 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000630 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000586 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000613 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000705 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000592 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000623 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000612 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000646 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000602 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000583 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000689 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000753 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000930 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000618 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000724 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000744 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000696 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000622 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000679 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000764 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000741 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000697 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000842 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000779 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000712 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000690 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.862966
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000788 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 12.040457
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 71756, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000825 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.991945
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 107634, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.41 MB) transferred to GPU in 0.000820 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 11.965123
# Men's LightGBM: RMSE = 8.2721, Brier = 0.0050
# Men's CatBoost: RMSE = 8.2818, Brier = 0.0050
#
# Tuning Women's models:
# Women's LinearRegression: RMSE = 11.0282, Brier = 0.0017
# Women's Ridge: RMSE = 11.0282, Brier = 0.0017
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Women's Lasso: RMSE = 11.0303, Brier = 0.0017
# Women's DecisionTree: RMSE = 10.7805, Brier = 0.0018
# Women's RandomForest: RMSE = 10.7444, Brier = 0.0018
# Women's ExtraTrees: RMSE = 10.8391, Brier = 0.0017
# Women's GradientBoosting: RMSE = 10.7430, Brier = 0.0019
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:10:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# Women's XGBoost: RMSE = 10.7835, Brier = 0.0017
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000516 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000538 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000499 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000540 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# ...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000552 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000596 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000641 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000650 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000542 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000603 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000559 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000534 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000637 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000617 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000540 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000563 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000503 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000542 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000545 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000664 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000630 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000648 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000623 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000613 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000706 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000636 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000684 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.374061
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47233, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000658 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.302140
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 47234, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.18 MB) transferred to GPU in 0.000787 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.332028
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 70850, number of used features: 1
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 1 dense feature groups (0.27 MB) transferred to GPU in 0.000659 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14.336076
# Women's LightGBM: RMSE = 10.7870, Brier = 0.0017
# Women's CatBoost: RMSE = 10.8110, Brier = 0.0017
#
# Men's Model Results:
# {'LinearRegression': {'rmse': 8.794744317796573, 'brier': 0.00383171291750491}, 'Ridge': {'rmse': 8.794744325241956, 'brier': 0.0038317129005964947}, 'Lasso': {'rmse': 8.797656786667428, 'brier': 0.0038251534547471366}, 'DecisionTree': {'rmse': 8.258215601994127, 'brier': 0.00517754397135276}, 'RandomForest': {'rmse': 8.269349779659146, 'brier': 0.005137109260967347}, 'ExtraTrees': {'rmse': 8.403931323864326, 'brier': 0.00469836550459862}, 'GradientBoosting': {'rmse': 8.26577739057563, 'brier': 0.0050732971337460585}, 'XGBoost': {'rmse': 8.265174276336746, 'brier': 0.005048027}, 'LightGBM': {'rmse': 8.272063079282848, 'brier': 0.0050403778354839255}, 'CatBoost': {'rmse': 8.281781242727433, 'brier': 0.004992506398819747}}
#
# Women's Model Results:
# {'LinearRegression': {'rmse': 11.0282373084117, 'brier': 0.001674372451001369}, 'Ridge': {'rmse': 11.02823731752795, 'brier': 0.0016743724262436627}, 'Lasso': {'rmse': 11.030262156541163, 'brier': 0.0016689064630510298}, 'DecisionTree': {'rmse': 10.780515250840462, 'brier': 0.0017842392831613038}, 'RandomForest': {'rmse': 10.744360059275293, 'brier': 0.0017893184347683201}, 'ExtraTrees': {'rmse': 10.839121353185645, 'brier': 0.0016664090758825895}, 'GradientBoosting': {'rmse': 10.742981910746568, 'brier': 0.0018834253500358458}, 'XGBoost': {'rmse': 10.783526359588224, 'brier': 0.0017280964}, 'LightGBM': {'rmse': 10.786992558685128, 'brier': 0.0017344500797303042}, 'CatBoost': {'rmse': 10.811036931267656, 'brier': 0.0017114435469074638}}

# %%
# %% [markdown]
# ## 8. Generate Validation Predictions
# 
# Create DataFrames of predictions on the validation set (2024) for both men’s and women’s models.

# %% [code]
# Men’s validation predictions.
val_preds_m = pd.DataFrame({"ID": np.arange(len(X_val_m))})
for name, model in men_best_models.items():
    val_preds_m[name] = model.predict(X_val_m)

# Women’s validation predictions.
val_preds_w = pd.DataFrame({"ID": np.arange(len(X_val_w))})
for name, model in women_best_models.items():
    val_preds_w[name] = model.predict(X_val_w)

print("Validation predictions generated for both men and women.")
# Out:
# Validation predictions generated for both men and women.

# %%
# %% [markdown]
# ## 9. Load and Parse 2025 Submission File
# 
# For the final submission, we load the 2025 test file. Many competition submission files do not include separate Season, Team1, and Team2 columns;
# instead, they encode these in the "ID" column (e.g., "2025_1101_1102"). Here, we parse that field.
# 
# **Change:** We now parse the submission file for 2025 instead of simulating a dummy DataFrame.

# %% [code]
df_sub = pd.read_csv(os.path.join(data_folder, "SampleSubmissionStage2.csv"))

# Parse the ID field to extract Season, Team1, and Team2.
def parse_id(match_id):
    season, t1, t2 = match_id.split('_')
    return int(season), int(t1), int(t2)

df_sub["Season"] = df_sub["ID"].apply(lambda x: parse_id(x)[0])
df_sub["Team1"] = df_sub["ID"].apply(lambda x: parse_id(x)[1])
df_sub["Team2"] = df_sub["ID"].apply(lambda x: parse_id(x)[2])
print("Submission file loaded and parsed for 2025.")
# Out:
# Submission file loaded and parsed for 2025.

# %%
# %% [markdown]
# ## 10. Define Prediction Function and Generate Submission Files
# 
# The `predict_match` function uses the combined ratings and tuned models (for men’s and women’s separately)
# to predict the margin. Then we generate one submission file for every combination of men’s and women’s tuned models.
# 
# **Change:** The prediction function now uses the actual combined ratings (which are computed using our real Elo ratings).

# %% [code]
def predict_match(row, men_model_name, women_model_name):
    # Get season, team IDs from the parsed submission DataFrame.
    s = row["Season"]
    t1 = row["Team1"]
    t2 = row["Team2"]
    # For men’s games (team IDs < 2000)
    if t1 < 2000 and t2 < 2000:
        diff = combined_rating_men.get(t1, 1500) - combined_rating_men.get(t2, 1500)
        pred = men_best_models[men_model_name].predict(np.array([[diff]]))[0]
    # For women’s games (team IDs >= 3000)
    elif t1 >= 3000 and t2 >= 3000:
        diff = combined_rating_women.get(t1, 1500) - combined_rating_women.get(t2, 1500)
        pred = women_best_models[women_model_name].predict(np.array([[diff]]))[0]
    else:
        pred = 0.5  # fallback for mixed matchups
    return pred

submission_folder = "combined_submissions"
os.makedirs(submission_folder, exist_ok=True)
combined_submission_files = []

for m_name in men_best_models.keys():
    for w_name in women_best_models.keys():
        df_sub["Pred"] = df_sub.apply(lambda row: predict_match(row, m_name, w_name), axis=1)
        fname = os.path.join(submission_folder, f"submission_{m_name}_{w_name}.csv")
        df_sub[["ID", "Pred"]].to_csv(fname, index=False)
        combined_submission_files.append(fname)
        print(f"Saved submission file: {fname}")
# Out:
# Saved submission file: combined_submissions/submission_LinearRegression_LinearRegression.csv
# Saved submission file: combined_submissions/submission_LinearRegression_Ridge.csv
# Saved submission file: combined_submissions/submission_LinearRegression_Lasso.csv
# Saved submission file: combined_submissions/submission_LinearRegression_DecisionTree.csv
# Saved submission file: combined_submissions/submission_LinearRegression_RandomForest.csv
# Saved submission file: combined_submissions/submission_LinearRegression_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_LinearRegression_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_LinearRegression_XGBoost.csv
# Saved submission file: combined_submissions/submission_LinearRegression_LightGBM.csv
# Saved submission file: combined_submissions/submission_LinearRegression_CatBoost.csv
# Saved submission file: combined_submissions/submission_Ridge_LinearRegression.csv
# Saved submission file: combined_submissions/submission_Ridge_Ridge.csv
# Saved submission file: combined_submissions/submission_Ridge_Lasso.csv
# Saved submission file: combined_submissions/submission_Ridge_DecisionTree.csv
# Saved submission file: combined_submissions/submission_Ridge_RandomForest.csv
# Saved submission file: combined_submissions/submission_Ridge_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_Ridge_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_Ridge_XGBoost.csv
# Saved submission file: combined_submissions/submission_Ridge_LightGBM.csv
# Saved submission file: combined_submissions/submission_Ridge_CatBoost.csv
# Saved submission file: combined_submissions/submission_Lasso_LinearRegression.csv
# Saved submission file: combined_submissions/submission_Lasso_Ridge.csv
# Saved submission file: combined_submissions/submission_Lasso_Lasso.csv
# Saved submission file: combined_submissions/submission_Lasso_DecisionTree.csv
# Saved submission file: combined_submissions/submission_Lasso_RandomForest.csv
# Saved submission file: combined_submissions/submission_Lasso_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_Lasso_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_Lasso_XGBoost.csv
# Saved submission file: combined_submissions/submission_Lasso_LightGBM.csv
# Saved submission file: combined_submissions/submission_Lasso_CatBoost.csv
# Saved submission file: combined_submissions/submission_DecisionTree_LinearRegression.csv
# Saved submission file: combined_submissions/submission_DecisionTree_Ridge.csv
# Saved submission file: combined_submissions/submission_DecisionTree_Lasso.csv
# Saved submission file: combined_submissions/submission_DecisionTree_DecisionTree.csv
# Saved submission file: combined_submissions/submission_DecisionTree_RandomForest.csv
# Saved submission file: combined_submissions/submission_DecisionTree_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_DecisionTree_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_DecisionTree_XGBoost.csv
# Saved submission file: combined_submissions/submission_DecisionTree_LightGBM.csv
# Saved submission file: combined_submissions/submission_DecisionTree_CatBoost.csv
# Saved submission file: combined_submissions/submission_RandomForest_LinearRegression.csv
# Saved submission file: combined_submissions/submission_RandomForest_Ridge.csv
# Saved submission file: combined_submissions/submission_RandomForest_Lasso.csv
# Saved submission file: combined_submissions/submission_RandomForest_DecisionTree.csv
# Saved submission file: combined_submissions/submission_RandomForest_RandomForest.csv
# Saved submission file: combined_submissions/submission_RandomForest_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_RandomForest_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_RandomForest_XGBoost.csv
# Saved submission file: combined_submissions/submission_RandomForest_LightGBM.csv
# Saved submission file: combined_submissions/submission_RandomForest_CatBoost.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_LinearRegression.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_Ridge.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_Lasso.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_DecisionTree.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_RandomForest.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_XGBoost.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_LightGBM.csv
# Saved submission file: combined_submissions/submission_ExtraTrees_CatBoost.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_LinearRegression.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_Ridge.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_Lasso.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_DecisionTree.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_RandomForest.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_XGBoost.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_LightGBM.csv
# Saved submission file: combined_submissions/submission_GradientBoosting_CatBoost.csv
# Saved submission file: combined_submissions/submission_XGBoost_LinearRegression.csv
# Saved submission file: combined_submissions/submission_XGBoost_Ridge.csv
# Saved submission file: combined_submissions/submission_XGBoost_Lasso.csv
# Saved submission file: combined_submissions/submission_XGBoost_DecisionTree.csv
# Saved submission file: combined_submissions/submission_XGBoost_RandomForest.csv
# Saved submission file: combined_submissions/submission_XGBoost_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_XGBoost_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_XGBoost_XGBoost.csv
# Saved submission file: combined_submissions/submission_XGBoost_LightGBM.csv
# Saved submission file: combined_submissions/submission_XGBoost_CatBoost.csv
# Saved submission file: combined_submissions/submission_LightGBM_LinearRegression.csv
# Saved submission file: combined_submissions/submission_LightGBM_Ridge.csv
# Saved submission file: combined_submissions/submission_LightGBM_Lasso.csv
# Saved submission file: combined_submissions/submission_LightGBM_DecisionTree.csv
# Saved submission file: combined_submissions/submission_LightGBM_RandomForest.csv
# Saved submission file: combined_submissions/submission_LightGBM_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_LightGBM_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_LightGBM_XGBoost.csv
# Saved submission file: combined_submissions/submission_LightGBM_LightGBM.csv
# Saved submission file: combined_submissions/submission_LightGBM_CatBoost.csv
# Saved submission file: combined_submissions/submission_CatBoost_LinearRegression.csv
# Saved submission file: combined_submissions/submission_CatBoost_Ridge.csv
# Saved submission file: combined_submissions/submission_CatBoost_Lasso.csv
# Saved submission file: combined_submissions/submission_CatBoost_DecisionTree.csv
# Saved submission file: combined_submissions/submission_CatBoost_RandomForest.csv
# Saved submission file: combined_submissions/submission_CatBoost_ExtraTrees.csv
# Saved submission file: combined_submissions/submission_CatBoost_GradientBoosting.csv
# Saved submission file: combined_submissions/submission_CatBoost_XGBoost.csv
# Saved submission file: combined_submissions/submission_CatBoost_LightGBM.csv
# Saved submission file: combined_submissions/submission_CatBoost_CatBoost.csv

# %%
# %% [markdown]
# ## 11. Combine Submission Predictions into Ensembles
# 
# We now load all the combined submission files and build ensemble predictions.
# 
# We also compute ensemble performance using corrected Brier score calculations. The Brier score here is computed by:
# 
# \[
# \text{Brier} = \frac{1}{N}\sum_{i=1}^{N}\left(p_i - y_i\right)^2,
# \]
# 
# where we convert margin predictions to win probabilities via a logistic transform.
# 
# **Change:** The `compute_ensemble_scores` function now uses a logistic transform (`margin_to_probability`) before computing the Brier score.
# We assume the ground truth win probability is 1 (i.e. the winning team won).

# %% [code]
def margin_to_probability(margin, scale=10.0):
    return 1.0 / (1 + 10 ** (-margin/scale))

def compute_ensemble_scores(pred_df, y_true, model_list, method="simple", combined_rmse_dict=None, scale=10.0):
    if method == "simple":
        ens_margin = pred_df[model_list].mean(axis=1)
    elif method == "weighted":
        weights = np.array([1/combined_rmse_dict[m] for m in model_list])
        weights = weights / np.sum(weights)
        ens_margin = np.sum(pred_df[model_list].values * weights, axis=1)
    else:
        raise ValueError("Method not supported.")
    rmse = np.sqrt(mean_squared_error(y_true, ens_margin))
    ens_prob = margin_to_probability(ens_margin, scale=scale)
    # For our validation set, ground truth win probability is 1 (since winner always wins)
    brier = np.mean((ens_prob - 1)**2)
    return rmse, brier

# For demonstration purposes, we simulate a DataFrame "combined_preds_df" by loading the predictions
# from our combined submission files. In production, ensure that the order of IDs matches your test set.
combined_preds_df = pd.DataFrame()
for fname in combined_submission_files:
    temp = pd.read_csv(fname)
    # Use a column name based on the file name (remove prefix/suffix)
    col_name = os.path.basename(fname).replace("submission_", "").replace(".csv", "")
    combined_preds_df[col_name] = temp["Pred"]

# For ensemble evaluation, we need dummy true values.
# Since all games in our validation (or test) set are wins by the predicted winning team, we use ones.
dummy_true = np.ones(len(combined_preds_df))

# Create a dummy combined RMSE dictionary by averaging men's and women's RMSE.
combined_rmse_dict = {}
for m in men_results:
    for w in women_results:
        key = f"{m}_{w}"
        combined_rmse_dict[key] = (men_results[m]["rmse"] + women_results[w]["rmse"]) / 2

sorted_combined = sorted(combined_rmse_dict.items(), key=lambda x: x[1])
sorted_combined_names = [x[0] for x in sorted_combined]

ensemble_sizes = [2, 3, 5, 7, 9, 11]
ensemble_results = []
for size in ensemble_sizes:
    models_used = sorted_combined_names[:size]
    rmse_simple, brier_simple = compute_ensemble_scores(combined_preds_df, dummy_true, models_used, method="simple", scale=10.0)
    rmse_weighted, brier_weighted = compute_ensemble_scores(combined_preds_df, dummy_true, models_used, method="weighted", combined_rmse_dict=combined_rmse_dict, scale=10.0)
    ensemble_results.append({
        "Ensemble": f"top{size}",
        "Method": "simple",
        "RMSE": rmse_simple,
        "Brier": brier_simple
    })
    ensemble_results.append({
        "Ensemble": f"top{size}",
        "Method": "weighted",
        "RMSE": rmse_weighted,
        "Brier": brier_weighted
    })

ensemble_scores_df = pd.DataFrame(ensemble_results)
print("Ensemble performance on combined predictions:")
print(ensemble_scores_df)

plt.figure(figsize=(8,6))
for method in ["simple", "weighted"]:
    subset = ensemble_scores_df[ensemble_scores_df["Method"]==method]
    sizes = [int(x.replace("top","")) for x in subset["Ensemble"]]
    plt.plot(sizes, subset["RMSE"], marker='o', label=method)
plt.xlabel("Number of top combined models in ensemble")
plt.ylabel("RMSE")
plt.title("Ensemble Performance on Combined Predictions")
plt.legend()
plt.show()
# Out:
# Ensemble performance on combined predictions:
#    Ensemble    Method       RMSE     Brier
# 0      top2    simple  12.382608  0.004664
# 1      top2  weighted  12.382610  0.004664
# 2      top3    simple  12.400597  0.004692
# 3      top3  weighted  12.400594  0.004692
# 4      top5    simple  12.381217  0.004747
# 5      top5  weighted  12.381219  0.004747
# 6      top7    simple  12.366472  0.004808
# 7      top7  weighted  12.366475  0.004808
# 8      top9    simple  12.363898  0.004823
# 9      top9  weighted  12.363900  0.004823
# 10    top11    simple  12.365259  0.004789
# 11    top11  weighted  12.365258  0.004789

# %%
# %% [markdown]
# ## 12. Final Submission for 2025
# 
# Suppose we decide the best ensemble is, for example, the weighted ensemble with top 3 combined models.
# We now compute final predictions on the actual 2025 test set.
# 
# **Change:** We now load the actual 2025 submission file (which we already parsed) and use it to create the final submission.
# Final submission is saved as "final_submission_top3_weighted.csv".

# %% [code]
# Decide on best ensemble (here using top3 weighted ensemble as an example)
best_ensemble = sorted_combined_names[:3]
print("Best ensemble models (weighted, top3):", best_ensemble)

# To compute final predictions, we use the combined_preds_df (assuming it is produced from the 2025 test set)
final_weights = np.array([1/combined_rmse_dict[m] for m in best_ensemble])
final_weights = final_weights / np.sum(final_weights)
final_preds = np.sum(combined_preds_df[best_ensemble].values * final_weights, axis=1)

# Load the 2025 test submission file (already parsed into df_sub)
df_sub_test = pd.read_csv(os.path.join(data_folder, "SampleSubmissionStage2.csv"))
# Parse its ID field to add Season, Team1, and Team2 if needed.
df_sub_test["Season"] = df_sub_test["ID"].apply(lambda x: parse_id(x)[0])
df_sub_test["Team1"] = df_sub_test["ID"].apply(lambda x: parse_id(x)[1])
df_sub_test["Team2"] = df_sub_test["ID"].apply(lambda x: parse_id(x)[2])
df_sub_test["Pred"] = final_preds
submission_filename = "final_submission_top3_weighted.csv"
df_sub_test[["ID", "Pred"]].to_csv(submission_filename, index=False)
print(f"Final submission saved as {submission_filename}")
# Out:
# Best ensemble models (weighted, top3): ['DecisionTree_GradientBoosting', 'DecisionTree_RandomForest', 'XGBoost_GradientBoosting']
# Final submission saved as final_submission_top3_weighted.csv
